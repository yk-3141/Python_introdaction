# %% [markdown]
# <a href="https://colab.research.google.com/github/yk-3141/Python-_introdaction/blob/main/Python%E5%85%A5%E9%96%80_3%E7%AB%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **構造化定理**
#
# 順次・分岐・繰り返しの3つの制御構造を組み合わせれば、どんなに複雑なプログラムでも、理論上作成可能である

# %%
# 3-1 いつも同じことを言うチャットボット
name = input('あなたの名前を教えてください >>')
print(f'{name}さん、こんにちは')
food = input(f'{name}さんの好きな食べ物を教えてください >>')
print(f'私も{food}が好きですよ')
# Out:
# あなたの名前を教えてください >>ゆき
# ゆきさん、こんにちは
# ゆきさんの好きな食べ物を教えてください >>
# 私もが好きですよ

# %%
# 3-2 答えが分岐するチャットボット
name = input('あなたの名前を教えてください >>')
print(f'{name}さん、こんにちは')
food = input(f'{name}さんの好きな食べ物を教えてください >>')
if food == 'カレー':
  print('素敵です。カレーは最高ですよね!!')
else:
  print('私も{food}が好きですよ')
# Out:
# あなたの名前を教えてください >>yuki
# yukiさん、こんにちは
# yukiさんの好きな食べ物を教えてください >>カレー
# 素敵です。カレーは最高ですよね!!

# %%
# 3-3 常に追試を受けることになる判定プログラム
score = int(input('試験の点数を入力してください'))
if score >= 60:
  print('合格!')
  print('よくがんばりましたね')
else:
  print('残念ながら不合格です')
  print('追試を受けてください')
# Out:
# 試験の点数を入力してください70
# 合格!
# よくがんばりましたね

# %%
# 3-4 どんなカツカレーでも絶賛するチャットボット
name = input('あなたの名前を教えてください >>')
print(f'{name}さん、こんにちは')
food = input(f'{name}さんの好きな食べ物を教えてください >>')
if 'カレー' in food:
  print('素敵です。カレーは最高ですよね!!')
else:
  print(f'私も{food}が好きですよ')
# Out:
# あなたの名前を教えてください >>あ
# あさん、こんにちは
# あさんの好きな食べ物を教えてください >>カレー
# 素敵です。カレーは最高ですよね!!

# %%
# 3-5 100点があるかどうか調べる
scores = [80, 100, 20, 60]
if 100 in scores:
  print('100点満点の試験があったんですね。おめでとう!')
else:
  print('次はどれか1つでも100点を取ろう')
# Out:
# 100点満点の試験があったんですね。おめでとう!

# %%
# 3-6 ディクショナリのキーをチェックする
scores = {'network':60, 'database':80, 'security':50}

key = input('追加する科目名を入力してください >>')
if key in scores:
  print('既に登録済みです')
else:
  data = int(input('得点を入力してください >>'))
  scores[key] = data
print(scores)
# Out:
# 追加する科目名を入力してください >>management
# 得点を入力してください >>90
# {'network': 60, 'database': 80, 'security': 50, 'management': 90}

# %%
# 3-7 条件式の評価結果を確認する
score = int(input('試験の点数を入力 >>'))
print(score >= 60)
# Out:
# 試験の点数を入力 >>90
# True

# %%
# 3-8 elseブロックのない分岐
name = input('あなたの名前を入力してください >>')
print(f'{name}さん、こんにちは')
if name == '松田':
  print('松田さんに会えて嬉しいです')
food = input(f'{name}さんの好きな食べ物を教えてください >>')
if 'カレー' in food:
  print('素敵です。とにかくカレーは最高ですよね!!')
else:
  print(f'私も{food}が好きですよ')
# Out:
# あなたの名前を入力してください >>ai
# aiさん、こんにちは
# aiさんの好きな食べ物を教えてください >>カレー
# 素敵です。とにかくカレーは最高ですよね!!

# %%
# 3-9 多分岐するif文
score = int(input('試験の点数を入力してください >>'))
if score < 0 or score > 100:
  print('異常な得点です')
elif score >= 60:
  print('合格!')
  print('よくがんばりましたね')
else:
  print('残念ながら不合格です')
  print('追試を受けてください')
# Out:
# 試験の点数を入力してください >>67
# 合格!
# よくがんばりましたね

# %%
# 3-10 晩御飯をレコメンドするチャットボット
print('全ての質問にyまたはnで答えてください')
okane_aruka = input('お金に余裕はありますか？　＞＞')
if okane_aruka == 'y':
  onaka_suiteruka = input('お腹が空いていますか？　＞＞')
  nomitai_kibunka = input('ビールを飲みたいですか？　＞＞')
  if onaka_suiteruka == 'y' and nomitai_kibunka == 'y':
    print('焼肉はいかがですか')
  elif onaka_suiteruka == 'y':
    print('カレーはいかがですか')
  elif nomitai_kibunka == 'y':
    print('焼き鳥はいかがですか')
  else:
    print('パスタはいかがですか')
  yashyoku_iruka = input('夜食は必要ですか？　＞＞')
  if yashyoku_iruka == 'y':
    print('コンビニのチキンはいかがですか')
else:
  print('家で食べましょう')
# Out:
# 全ての質問にyまたはnで答えてください
# お金に余裕はありますか？　＞＞y
# お腹が空いていますか？　＞＞n
# ビールを飲みたいですか？　＞＞y
# 焼き鳥はいかがですか
# 夜食は必要ですか？　＞＞n

# %%
# 練習3-3
# (1)
print('yかnを入力してください')
isError = input('エラーが発生しましたか？　＞＞')
n = int(input('数字を入力してください ＞＞'))

if isError == 'y' and n < 100:
  print('画面が出力されます')
# Out:
# yかnを入力してください
# エラーが発生しましたか？　＞＞n
# 数字を入力してください ＞＞９

# %%
# (2)
number = int(input('数字を入力してください　＞＞'))
if number %2 == 0:
  print('数値は偶数です')
elif number %2 == 1:
  print('数値は奇数です')
else:
  print('偶数でも奇数でもありません')
# Out:
# 数字を入力してください　＞＞0
# 数値は偶数です

# %%
# (3)
greeding = (input('挨拶を入力してください　＞＞'))
if greeding == 'こんにちは':
  print('ようこそ！')
elif greeding == '景気は？':
  print('ぼちぼちです')
elif greeding == 'さようなら':
  print('お元気で！')
else:
  print('どうしました？')
# Out:
# 挨拶を入力してください　＞＞こんにちは
# ようこそ！

# %%
# 練習3-4
